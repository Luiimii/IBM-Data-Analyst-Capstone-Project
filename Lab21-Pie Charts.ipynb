# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 174.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 203.4 MB/s eta 0:00:00
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 173.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 160.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 88.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 162.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# --2025-08-27 14:09:05--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  61.8MB/s    in 2.5s
#
# 2025-08-27 14:09:07 (61.8 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
import sqlite3
conn = sqlite3.connect("survey-results-public.sqlite")

# %%
##Write your code here
query = "SELECT DatabaseWantToWorkWith FROM main"
df = pd.read_sql_query(query, conn)

db_df = df.dropna(subset=['DatabaseWantToWorkWith']).copy()

db_df['DatabaseWantToWorkWith'] = db_df['DatabaseWantToWorkWith'].str.split(';')
db_df = db_df.explode('DatabaseWantToWorkWith')
db_df['DatabaseWantToWorkWith'] = db_df['DatabaseWantToWorkWith'].str.strip()

db_counts = db_df['DatabaseWantToWorkWith'].value_counts().nlargest(5)

plt.figure(figsize=(8, 8))
plt.pie(
    db_counts,
    labels=db_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Paired.colors
)
plt.title("Top 5 Databases Respondents Want to Work With", fontsize=14)
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
##Write your code here
query = "SELECT DevType FROM main"
df = pd.read_sql_query(query, conn)

dev_df = df.dropna(subset=['DevType']).copy()
dev_counts = dev_df['DevType'].value_counts().nlargest(5)

plt.figure(figsize=(8, 8))
plt.pie(
    dev_counts,
    labels=dev_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Set3.colors
)
plt.title("Top 5 Developer Roles", fontsize=14)
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
##Write your code here
query = 'SELECT "OpSysProfessional use" FROM main'
df = pd.read_sql_query(query, conn)

os_df = df.dropna(subset=['OpSysProfessional use']).copy()

os_df['OpSysProfessional use'] = os_df['OpSysProfessional use'].str.split(';')
os_df = os_df.explode('OpSysProfessional use')
os_df['OpSysProfessional use'] = os_df['OpSysProfessional use'].str.strip()

os_counts = os_df['OpSysProfessional use'].value_counts()

top_os = os_counts.nlargest(5)

plt.figure(figsize=(8, 8))
plt.pie(
    top_os,
    labels=top_os.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Pastel1.colors
)
plt.title("Top Operating Systems Used Professionally", fontsize=14)
plt.show()

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
##Write your code here
query = "SELECT LanguageHaveWorkedWith FROM main"
df = pd.read_sql_query(query, conn)

lang_df = df.dropna(subset=['LanguageHaveWorkedWith']).copy()

lang_df['LanguageHaveWorkedWith'] = lang_df['LanguageHaveWorkedWith'].str.split(';')
lang_df = lang_df.explode('LanguageHaveWorkedWith')
lang_df['LanguageHaveWorkedWith'] = lang_df['LanguageHaveWorkedWith'].str.strip()

lang_counts = lang_df['LanguageHaveWorkedWith'].value_counts().nlargest(5)

plt.figure(figsize=(8, 8))
plt.pie(
    lang_counts,
    labels=lang_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Set2.colors
)
plt.title("Top 5 Programming Languages Respondents Have Worked With", fontsize=14)
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
##Write your code here
query = "SELECT NEWCollabToolsHaveWorkedWith FROM main"
df = pd.read_sql_query(query, conn)

tools_df = df.dropna(subset=['NEWCollabToolsHaveWorkedWith']).copy()

tools_df['NEWCollabToolsHaveWorkedWith'] = tools_df['NEWCollabToolsHaveWorkedWith'].str.split(';')
tools_df = tools_df.explode('NEWCollabToolsHaveWorkedWith')
tools_df['NEWCollabToolsHaveWorkedWith'] = tools_df['NEWCollabToolsHaveWorkedWith'].str.strip()

tools_counts = tools_df['NEWCollabToolsHaveWorkedWith'].value_counts().nlargest(5)

plt.figure(figsize=(8, 8))
plt.pie(
    tools_counts,
    labels=tools_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Paired.colors
)
plt.title("Top 5 Collaboration Tools Used Professionally", fontsize=14)
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
##Write your code here
query = "SELECT LanguageAdmired FROM main"
df = pd.read_sql_query(query, conn)

admired_df = df.dropna(subset=['LanguageAdmired']).copy()

admired_df['LanguageAdmired'] = admired_df['LanguageAdmired'].str.split(';')
admired_df = admired_df.explode('LanguageAdmired')
admired_df['LanguageAdmired'] = admired_df['LanguageAdmired'].str.strip()

admired_counts = admired_df['LanguageAdmired'].value_counts().nlargest(5)

plt.figure(figsize=(8, 8))
plt.pie(
    admired_counts,
    labels=admired_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Set3.colors
)
plt.title("Top 5 Most Admired Programming Languages", fontsize=14)
plt.show()

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
##Write your code here
query = 'SELECT "AIToolCurrently Using" FROM main'
df = pd.read_sql_query(query, conn)

ai_df = df.dropna(subset=['AIToolCurrently Using']).copy()

ai_df['AIToolCurrently Using'] = ai_df['AIToolCurrently Using'].str.split(';')
ai_df = ai_df.explode('AIToolCurrently Using')
ai_df['AIToolCurrently Using'] = ai_df['AIToolCurrently Using'].str.strip()

ai_counts = ai_df['AIToolCurrently Using'].value_counts().nlargest(5)

plt.figure(figsize=(8, 8))
plt.pie(
    ai_counts,
    labels=ai_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Paired.colors
)
plt.title("Top 5 AI Tools Currently Used", fontsize=14)
plt.show()

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
##Write your code here
query = "SELECT WebframeWantToWorkWith FROM main"
df = pd.read_sql_query(query, conn)

web_df = df.dropna(subset=['WebframeWantToWorkWith']).copy()

web_df['WebframeWantToWorkWith'] = web_df['WebframeWantToWorkWith'].str.split(';')
web_df = web_df.explode('WebframeWantToWorkWith')
web_df['WebframeWantToWorkWith'] = web_df['WebframeWantToWorkWith'].str.strip()

web_counts = web_df['WebframeWantToWorkWith'].value_counts().nlargest(5)

plt.figure(figsize=(8, 8))
plt.pie(
    web_counts,
    labels=web_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Set2.colors
)
plt.title("Top 5 Preferred Web Frameworks", fontsize=14)
plt.show()

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
##Write your code here
query = "SELECT EmbeddedWantToWorkWith FROM main"
df = pd.read_sql_query(query, conn)

embedded_df = df.dropna(subset=['EmbeddedWantToWorkWith']).copy()

embedded_df['EmbeddedWantToWorkWith'] = embedded_df['EmbeddedWantToWorkWith'].str.split(';')
embedded_df = embedded_df.explode('EmbeddedWantToWorkWith')
embedded_df['EmbeddedWantToWorkWith'] = embedded_df['EmbeddedWantToWorkWith'].str.strip()

embedded_counts = embedded_df['EmbeddedWantToWorkWith'].value_counts().nlargest(5)

plt.figure(figsize=(8, 8))
plt.pie(
    embedded_counts,
    labels=embedded_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Pastel1.colors
)
plt.title("Top 5 Most Desired Embedded Technologies", fontsize=14)
plt.show()

# %%
conn.close()

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
